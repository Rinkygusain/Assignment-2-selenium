# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

driver=webdriver.Chrome(r'/Users/rinki/Downloads/chromedriver')

# %%
url='https://www.ambitionbox.com/'
driver.get(url)

#click on job option

search_job=driver.find_element_by_xpath('/html/body/div[1]/nav/nav/a[6]')
search_job

search_job.click()

#search job "Data Scientist"
job_title=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div/span/input')
job_title

job_title.send_keys("Data Scientist")

#search product
search_btn=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div/div/div/button")
search_btn

search_btn.click()

# %%
#search location

location=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[1]/p")
location
location.click()

#search Noida location

job_loc=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input')
job_loc

job_loc.send_keys("Noida")

#click on noida option
click_loc=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label')
click_loc.click()

# %%
# scrape job title
job_title=driver.find_elements_by_xpath('//a[@class="title noclick"]')
job_title

Job_title=[]
for i in job_title:
    Job_title.append(i.text)
Job_title

#scrape comp name
comp_name=driver.find_elements_by_xpath('//p[@class="company body-medium"]')
comp_name

Comp_name=[]
for i in comp_name: 
    Comp_name.append(i.text)
Comp_name


#scrape Location
loc=driver.find_elements_by_xpath('//p[@class="body-small-l"]')
loc

Loc=[]
for i in loc:
    Loc.append(i.text)
Loc[3:42:4]

#prepare dataframe
data=pd.DataFrame({})
data['Job_title']=Job_title
data['Comp_name']=Comp_name
data['Job_desc']=Job_desc[4:42:4]
data['Loc']=Loc[3:42:4]
data
# Out:
#                                            Job_title  \
# 0  Excellent Opportunity For Freshers For AI/ML, ...
# 1  HCL Hiring Data Scientist (Loc: Noida / Chenna...
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                  Data Scientist-II
# 5           HCL Tech Opening - Senior Data Scientist
# 6                                     Data Scientist
# 7      Urgent Requirement || Data Scientist || Noida
# 8                                     Data Scientist
# 9                         Opportunity | Tavant India
#
#                                            Comp_name  \
# 0  NTT DATA GLOBAL DELIVERY SERVICES PRIVATE LIMITED
# 1                           HCL Technologies Limited
# 2     Optum Global Solutions (India) Private Limited
# 3              WSP CONSULTANTS INDIA PRIVATE LIMITED
# 4                  Microsoft India (R and D) Pvt Ltd
# 5                               HCL Technologies Ltd
# ...
